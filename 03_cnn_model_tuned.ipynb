# %% [markdown]
# # Tuned VGG-like CNN for CIFAR-10

# %% [markdown]
# ## 1. Imports and paths

# %%
import os
import json
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import tensorflow as tf
import time

from tensorflow.keras import layers, models

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    CSVLogger,
    TensorBoard,
    Callback,
)

import seaborn as sns
import matplotlib.pyplot as plt

# Ensure project root is on sys.path so `utils` can be imported
cwd = Path.cwd()
if cwd.name.lower() == "notebooks":
    project_root = cwd.parent
elif cwd.name.lower() == "cifar10_project":
    project_root = cwd
elif (cwd / "cifar10_project").is_dir():
    project_root = cwd / "cifar10_project"
else:
    project_root = None

if project_root is not None and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from utils.ml_utils import (
    random_cutout,
    evaluate_and_log_model,
    format_duration,
    predict_and_resolve_labels,
    compute_confusion_matrix,
    build_classification_report,
    plot_confusion_matrix_notebook01,
    plot_training_curves_notebook01,
)

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU(s) detectada(s): {len(gpus)}")
else:
    print("Nenhuma GPU detectada. A correr em CPU.")
# Out:
# 2026-02-18 23:38:26.618852: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-18 23:38:26.651767: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-18 23:38:27.124704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# GPU(s) detectada(s): 1
# 2026-02-18 23:38:28.186969: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:28.219414: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:28.219470: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
PROJECT_ROOT = os.getcwd()
if os.path.basename(PROJECT_ROOT).lower() == 'notebooks':
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)
elif os.path.basename(PROJECT_ROOT).lower() != 'cifar10_project':
    candidate = os.path.join(PROJECT_ROOT, 'cifar10_project')
    if os.path.isdir(candidate):
        PROJECT_ROOT = candidate

DATA_DIR = os.path.join(PROJECT_ROOT, 'data')
PROCESSED_DIR = os.path.join(DATA_DIR, 'processed')
MODELS_DIR = os.path.join(PROJECT_ROOT, 'models')
REPORTS_DIR = os.path.join(PROJECT_ROOT, 'reports')
LOGS_ROOT = os.path.join(REPORTS_DIR, 'logs')

os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(REPORTS_DIR, exist_ok=True)
os.makedirs(LOGS_ROOT, exist_ok=True)

data_path = os.path.join(PROCESSED_DIR, 'cifar10_processed.npz')
log_dir = os.path.join(LOGS_ROOT, 'logs_03_tuned')
performance_report_path = os.path.join(DATA_DIR, 'model_performance_report.csv')
os.makedirs(log_dir, exist_ok=True)

print("Data path:", data_path)
print("Log dir:", log_dir)
print("Performance report path:", performance_report_path)
# Out:
# Data path: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/data/processed/cifar10_processed.npz
# Log dir: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/reports/logs/logs_03_tuned
# Performance report path: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/data/model_performance_report.csv

# %% [markdown]
# ## 2. Load processed data and convert labels to one-hot encoding

# %%
data = np.load(data_path)

x_train = data["x_train"]
y_train = data["y_train"]
x_val   = data["x_val"]
y_val   = data["y_val"]
x_test  = data["x_test"]
y_test  = data["y_test"]

print(x_train.shape, y_train.shape)
print(x_val.shape,   y_val.shape)
print(x_test.shape,  y_test.shape)
print("x_train range:", x_train.min(), x_train.max())
print("x_val range:", x_val.min(), x_val.max())
print("x_test range:", x_test.min(), x_test.max())
# Out:
# (40000, 32, 32, 3) (40000, 1)
# (10000, 32, 32, 3) (10000, 1)
# (10000, 32, 32, 3) (10000, 1)
# x_train range: 0.0 1.0
# x_val range: 0.0 1.0
# x_test range: 0.0 1.0

# %%
num_classes = 10

# Convert integer labels (shape (N,1) or (N,)) to one-hot
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_val = tf.keras.utils.to_categorical(y_val,   num_classes)
y_test = tf.keras.utils.to_categorical(y_test,  num_classes)

# %% [markdown]
# ## 3. Data augmentation (with Cutout) and generators

# %%
CUTOUT_MAX_HOLES = 1
CUTOUT_MIN_SIZE = 4
CUTOUT_MAX_SIZE = 8

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
    preprocessing_function=lambda img: random_cutout(
        img,
        max_holes=CUTOUT_MAX_HOLES,
        min_size=CUTOUT_MIN_SIZE,
        max_size=CUTOUT_MAX_SIZE,
    ),
)

val_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

batch_size = 64

train_generator = train_datagen.flow(
    x_train, y_train, batch_size=batch_size, shuffle=True
)
val_generator = val_datagen.flow(
    x_val, y_val, batch_size=batch_size, shuffle=False
)
test_generator = test_datagen.flow(
    x_test, y_test, batch_size=batch_size, shuffle=False
)

# %% [markdown]
# ## 4. Tuned VGG-BN model (4 blocks)

# %%
def build_vgg_bn_tuned(input_shape=(32, 32, 3), num_classes=10):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Block 1: 32
        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 2: 64
        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.30),

        # Block 3: 128
        layers.Conv2D(128, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(128, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.40),

        # Block 4: 256 (novo bloco)
        layers.Conv2D(256, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(256, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.40),

        # Classifier
        layers.Flatten(),
        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Dropout(0.4),
        layers.Dense(num_classes, activation="softmax"),
    ])
    return model

model = build_vgg_bn_tuned()
model.summary()
# Out:
# 2026-02-18 23:38:32.225177: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.225624: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.225716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.324158: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.324207: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.324214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-02-18 23:38:32.324241: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-18 23:38:32.324259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5527 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,442,090 (5.50 MB)
#  Trainable params: 1,439,658 (5.49 MB)
#  Non-trainable params: 2,432 (9.50 KB)

# %% [markdown]
# ## 5. Loss with label smoothing + AdamW + CosineDecay

# %%
epochs = 200
steps_per_epoch = len(x_train) // batch_size

initial_lr = 4e-4

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_lr,
    decay_steps=epochs * steps_per_epoch,
)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=5e-4,
)

loss = tf.keras.losses.CategoricalCrossentropy(
    from_logits=False,
    label_smoothing=0.05,
)

model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=["accuracy"],
)

# %% [markdown]
# ## 6. Experiment logger (CSV)

# %%
def log_model_performance(model, model_name, test_gen, history, train_time_sec, csv_path):
    """Backward-compatible wrapper around the reusable utility logger."""
    print(f"📊 Extracting final metrics for {model_name}...")
    if train_time_sec is not None:
        print(f"⏱️ Train time: {format_duration(train_time_sec)} ({train_time_sec:.2f} sec)")

    row = evaluate_and_log_model(
        model=model,
        model_name=model_name,
        data=test_gen,
        csv_path=csv_path,
        history=history,
        train_time_sec=train_time_sec,
        average="macro",
        verbose=0,
    )
    print(f"✅ Success! Performance log updated at: {csv_path}")
    return row

# %% [markdown]
# ## 7. Callbacks: EarlyStopping, ModelCheckpoint, TensorBoard, CSVLogger

# %%
checkpoint_path = os.path.join(MODELS_DIR, "vgg_bn_tuned_best.keras")
csv_log_path = os.path.join(DATA_DIR, "vgg_bn_tuned_history.csv")

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    verbose=1,
)

checkpoint = ModelCheckpoint(
    checkpoint_path,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=False,
    verbose=1,
)

csv_logger = CSVLogger(csv_log_path, append=False)

tensorboard_cb = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True,
    profile_batch="100,110",
)

callbacks = [
    early_stop,
    checkpoint,
    csv_logger,
    tensorboard_cb,
]
# Out:
# 2026-02-18 23:38:32.793451: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2026-02-18 23:38:32.793479: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2026-02-18 23:38:32.793500: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1239] Profiler found 1 GPUs
# 2026-02-18 23:38:32.817016: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2026-02-18 23:38:32.817131: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1364] CUPTI activity buffer flushed

# %% [markdown]
# ## 8. Training

# %%
start_time = time.time()

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    callbacks=callbacks,
    verbose=1,
)

end_time = time.time()
train_duration = end_time - start_time
print(f"Training time: {format_duration(train_duration)} ({train_duration:.2f} sec)")

log_model_performance(
    model=model,
    model_name="CNN - VGG-like Tuned",
    test_gen=test_generator,
    history=history,
    train_time_sec=train_duration,
    csv_path=performance_report_path,
)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771457916.367531   39503 service.cc:145] XLA service 0x7115d0002680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771457916.367582   39503 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-02-18 23:38:36.464299: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-18 23:38:36.910463: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#   9/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.0858 - loss: 3.0652
# I0000 00:00:1771457923.906061   39503 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 111/625 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.1379 - loss: 2.6841
# 2026-02-18 23:38:45.369893: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2026-02-18 23:38:45.369927: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2026-02-18 23:38:45.528422: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2026-02-18 23:38:45.541832: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1364] CUPTI activity buffer flushed
# 2026-02-18 23:38:45.550605: I external/local_xla/xla/backends/profiler/gpu/cupti_collector.cc:540]  GpuTracer has collected 3248 callback api events and 3234 activity events.
# 2026-02-18 23:38:45.553776: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2026-02-18 23:38:45.556059: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/reports/logs/logs_03_tuned/train/plugins/profile/2026_02_18_23_38_45/Desktop-Tupiblogger.xplane.pb
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2238 - loss: 2.2867
# Epoch 1: val_loss improved from None to 1.89395, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 1: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.2914 - loss: 2.0372 - val_accuracy: 0.3623 - val_loss: 1.8940
# Epoch 2/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4136 - loss: 1.6966
# Epoch 2: val_loss improved from 1.89395 to 1.66307, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 2: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4312 - loss: 1.6560 - val_accuracy: 0.4551 - val_loss: 1.6631
# Epoch 3/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4866 - loss: 1.5282
# Epoch 3: val_loss improved from 1.66307 to 1.53110, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 3: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.4980 - loss: 1.5025 - val_accuracy: 0.5106 - val_loss: 1.5311
# Epoch 4/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5389 - loss: 1.4130
# Epoch 4: val_loss improved from 1.53110 to 1.21744, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 4: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5505 - loss: 1.3871 - val_accuracy: 0.6173 - val_loss: 1.2174
# Epoch 5/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5815 - loss: 1.3094
# Epoch 5: val_loss did not improve from 1.21744
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5885 - loss: 1.2949 - val_accuracy: 0.5448 - val_loss: 1.4689
# Epoch 6/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6164 - loss: 1.2393
# Epoch 6: val_loss did not improve from 1.21744
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.6193 - loss: 1.2289 - val_accuracy: 0.6084 - val_loss: 1.3064
# Epoch 7/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6402 - loss: 1.1797
# Epoch 7: val_loss improved from 1.21744 to 1.16906, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 7: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6468 - loss: 1.1694 - val_accuracy: 0.6603 - val_loss: 1.1691
# Epoch 8/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6630 - loss: 1.1326
# Epoch 8: val_loss improved from 1.16906 to 1.00327, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 8: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6630 - loss: 1.1280 - val_accuracy: 0.7035 - val_loss: 1.0033
# Epoch 9/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6740 - loss: 1.1079
# Epoch 9: val_loss did not improve from 1.00327
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6737 - loss: 1.1017 - val_accuracy: 0.7066 - val_loss: 1.0068
# Epoch 10/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6846 - loss: 1.0760
# Epoch 10: val_loss did not improve from 1.00327
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6870 - loss: 1.0713 - val_accuracy: 0.7109 - val_loss: 1.0131
# Epoch 11/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7004 - loss: 1.0453
# Epoch 11: val_loss did not improve from 1.00327
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7026 - loss: 1.0381 - val_accuracy: 0.6626 - val_loss: 1.1481
# Epoch 12/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7104 - loss: 1.0275
# Epoch 12: val_loss improved from 1.00327 to 0.95045, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 12: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7076 - loss: 1.0219 - val_accuracy: 0.7345 - val_loss: 0.9505
# Epoch 13/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7215 - loss: 0.9947
# Epoch 13: val_loss improved from 0.95045 to 0.87105, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 13: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7198 - loss: 1.0000 - val_accuracy: 0.7647 - val_loss: 0.8710
# Epoch 14/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7245 - loss: 0.9858
# Epoch 14: val_loss did not improve from 0.87105
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7268 - loss: 0.9783 - val_accuracy: 0.7531 - val_loss: 0.9047
# Epoch 15/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7310 - loss: 0.9625
# Epoch 15: val_loss did not improve from 0.87105
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7328 - loss: 0.9632 - val_accuracy: 0.7147 - val_loss: 1.0280
# Epoch 16/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7390 - loss: 0.9427
# Epoch 16: val_loss improved from 0.87105 to 0.86373, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 16: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7385 - loss: 0.9476 - val_accuracy: 0.7702 - val_loss: 0.8637
# Epoch 17/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7452 - loss: 0.9374
# Epoch 17: val_loss improved from 0.86373 to 0.85828, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 17: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7437 - loss: 0.9381 - val_accuracy: 0.7775 - val_loss: 0.8583
# Epoch 18/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7494 - loss: 0.9281
# Epoch 18: val_loss did not improve from 0.85828
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7500 - loss: 0.9263 - val_accuracy: 0.7344 - val_loss: 0.9667
# Epoch 19/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7569 - loss: 0.9117
# Epoch 19: val_loss did not improve from 0.85828
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7552 - loss: 0.9124 - val_accuracy: 0.7489 - val_loss: 0.9247
# Epoch 20/200
# 609/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7565 - loss: 0.9061
# Epoch 20: val_loss did not improve from 0.85828
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7538 - loss: 0.9100 - val_accuracy: 0.7644 - val_loss: 0.8789
# Epoch 21/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7645 - loss: 0.8811
# Epoch 21: val_loss did not improve from 0.85828
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7617 - loss: 0.8915 - val_accuracy: 0.7362 - val_loss: 0.9663
# Epoch 22/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7681 - loss: 0.8795
# Epoch 22: val_loss improved from 0.85828 to 0.76100, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 22: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.7661 - loss: 0.8842 - val_accuracy: 0.8123 - val_loss: 0.7610
# Epoch 23/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7703 - loss: 0.8718
# Epoch 23: val_loss did not improve from 0.76100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7698 - loss: 0.8735 - val_accuracy: 0.8101 - val_loss: 0.7633
# Epoch 24/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7711 - loss: 0.8657
# Epoch 24: val_loss did not improve from 0.76100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7751 - loss: 0.8612 - val_accuracy: 0.7988 - val_loss: 0.7947
# Epoch 25/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7747 - loss: 0.8612
# Epoch 25: val_loss improved from 0.76100 to 0.75645, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 25: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.7766 - loss: 0.8591 - val_accuracy: 0.8113 - val_loss: 0.7564
# Epoch 26/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7837 - loss: 0.8457
# Epoch 26: val_loss did not improve from 0.75645
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7823 - loss: 0.8502 - val_accuracy: 0.7326 - val_loss: 0.9869
# Epoch 27/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7843 - loss: 0.8361
# Epoch 27: val_loss did not improve from 0.75645
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7849 - loss: 0.8380 - val_accuracy: 0.8093 - val_loss: 0.7775
# Epoch 28/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7872 - loss: 0.8316
# Epoch 28: val_loss did not improve from 0.75645
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7853 - loss: 0.8338 - val_accuracy: 0.8124 - val_loss: 0.7667
# Epoch 29/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7916 - loss: 0.8187
# Epoch 29: val_loss improved from 0.75645 to 0.72533, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 29: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7899 - loss: 0.8221 - val_accuracy: 0.8248 - val_loss: 0.7253
# Epoch 30/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7882 - loss: 0.8235
# Epoch 30: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7922 - loss: 0.8187 - val_accuracy: 0.8040 - val_loss: 0.7776
# Epoch 31/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7960 - loss: 0.8117
# Epoch 31: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7961 - loss: 0.8127 - val_accuracy: 0.8076 - val_loss: 0.7622
# Epoch 32/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7991 - loss: 0.7997
# Epoch 32: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7959 - loss: 0.8076 - val_accuracy: 0.7968 - val_loss: 0.8047
# Epoch 33/200
# 505/625 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7973 - loss: 0.8076
# Epoch 33: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8016 - loss: 0.7984 - val_accuracy: 0.8123 - val_loss: 0.7630
# Epoch 34/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8048 - loss: 0.7909
# Epoch 34: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8035 - loss: 0.7945 - val_accuracy: 0.8006 - val_loss: 0.7922
# Epoch 35/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8069 - loss: 0.7903
# Epoch 35: val_loss did not improve from 0.72533
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8055 - loss: 0.7901 - val_accuracy: 0.8199 - val_loss: 0.7374
# Epoch 36/200
# 617/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8102 - loss: 0.7779
# Epoch 36: val_loss improved from 0.72533 to 0.71732, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 36: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8066 - loss: 0.7825 - val_accuracy: 0.8265 - val_loss: 0.7173
# Epoch 37/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8072 - loss: 0.7795
# Epoch 37: val_loss improved from 0.71732 to 0.69220, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 37: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8072 - loss: 0.7813 - val_accuracy: 0.8384 - val_loss: 0.6922
# Epoch 38/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8121 - loss: 0.7689
# Epoch 38: val_loss did not improve from 0.69220
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8095 - loss: 0.7741 - val_accuracy: 0.8316 - val_loss: 0.7284
# Epoch 39/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8196 - loss: 0.7598
# Epoch 39: val_loss did not improve from 0.69220
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8149 - loss: 0.7666 - val_accuracy: 0.8271 - val_loss: 0.7326
# Epoch 40/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8162 - loss: 0.7602
# Epoch 40: val_loss did not improve from 0.69220
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8156 - loss: 0.7638 - val_accuracy: 0.7856 - val_loss: 0.8391
# Epoch 41/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8150 - loss: 0.7629
# Epoch 41: val_loss did not improve from 0.69220
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8138 - loss: 0.7682 - val_accuracy: 0.8137 - val_loss: 0.7609
# Epoch 42/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8184 - loss: 0.7554
# Epoch 42: val_loss did not improve from 0.69220
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8170 - loss: 0.7587 - val_accuracy: 0.8236 - val_loss: 0.7316
# Epoch 43/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8182 - loss: 0.7534
# Epoch 43: val_loss improved from 0.69220 to 0.67273, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 43: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8184 - loss: 0.7543 - val_accuracy: 0.8436 - val_loss: 0.6727
# Epoch 44/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8231 - loss: 0.7407
# Epoch 44: val_loss did not improve from 0.67273
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8214 - loss: 0.7450 - val_accuracy: 0.8270 - val_loss: 0.7302
# Epoch 45/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8250 - loss: 0.7420
# Epoch 45: val_loss did not improve from 0.67273
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8230 - loss: 0.7455 - val_accuracy: 0.8255 - val_loss: 0.7255
# Epoch 46/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8232 - loss: 0.7395
# Epoch 46: val_loss did not improve from 0.67273
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8229 - loss: 0.7428 - val_accuracy: 0.8414 - val_loss: 0.6925
# Epoch 47/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8253 - loss: 0.7357
# Epoch 47: val_loss did not improve from 0.67273
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8231 - loss: 0.7405 - val_accuracy: 0.8324 - val_loss: 0.7111
# Epoch 48/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8243 - loss: 0.7352
# Epoch 48: val_loss improved from 0.67273 to 0.67198, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 48: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8252 - loss: 0.7353 - val_accuracy: 0.8474 - val_loss: 0.6720
# Epoch 49/200
# 587/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8338 - loss: 0.7250
# Epoch 49: val_loss did not improve from 0.67198
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8295 - loss: 0.7305 - val_accuracy: 0.8215 - val_loss: 0.7281
# Epoch 50/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8299 - loss: 0.7255
# Epoch 50: val_loss improved from 0.67198 to 0.67146, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 50: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8296 - loss: 0.7252 - val_accuracy: 0.8484 - val_loss: 0.6715
# Epoch 51/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8317 - loss: 0.7240
# Epoch 51: val_loss improved from 0.67146 to 0.66648, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 51: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8322 - loss: 0.7243 - val_accuracy: 0.8497 - val_loss: 0.6665
# Epoch 52/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8312 - loss: 0.7196
# Epoch 52: val_loss did not improve from 0.66648
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8306 - loss: 0.7204 - val_accuracy: 0.8499 - val_loss: 0.6734
# Epoch 53/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8380 - loss: 0.7097
# Epoch 53: val_loss did not improve from 0.66648
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8355 - loss: 0.7139 - val_accuracy: 0.8388 - val_loss: 0.7015
# Epoch 54/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8372 - loss: 0.7064
# Epoch 54: val_loss did not improve from 0.66648
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8344 - loss: 0.7127 - val_accuracy: 0.8479 - val_loss: 0.6830
# Epoch 55/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8341 - loss: 0.7102
# Epoch 55: val_loss improved from 0.66648 to 0.65789, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 55: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8352 - loss: 0.7112 - val_accuracy: 0.8550 - val_loss: 0.6579
# Epoch 56/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8376 - loss: 0.7135
# Epoch 56: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8382 - loss: 0.7092 - val_accuracy: 0.8235 - val_loss: 0.7392
# Epoch 57/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8402 - loss: 0.7003
# Epoch 57: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8374 - loss: 0.7055 - val_accuracy: 0.8481 - val_loss: 0.6742
# Epoch 58/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8423 - loss: 0.6943
# Epoch 58: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8407 - loss: 0.7001 - val_accuracy: 0.8044 - val_loss: 0.7823
# Epoch 59/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8407 - loss: 0.6983
# Epoch 59: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8385 - loss: 0.7039 - val_accuracy: 0.8339 - val_loss: 0.7058
# Epoch 60/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8445 - loss: 0.6911
# Epoch 60: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8437 - loss: 0.6922 - val_accuracy: 0.8349 - val_loss: 0.7073
# Epoch 61/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8417 - loss: 0.6953
# Epoch 61: val_loss did not improve from 0.65789
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8425 - loss: 0.6947 - val_accuracy: 0.8357 - val_loss: 0.7105
# Epoch 62/200
# 512/625 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8379 - loss: 0.7019
# Epoch 62: val_loss improved from 0.65789 to 0.64930, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 62: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8422 - loss: 0.6959 - val_accuracy: 0.8608 - val_loss: 0.6493
# Epoch 63/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8477 - loss: 0.6762
# Epoch 63: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8461 - loss: 0.6841 - val_accuracy: 0.8393 - val_loss: 0.6998
# Epoch 64/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8469 - loss: 0.6820
# Epoch 64: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8458 - loss: 0.6864 - val_accuracy: 0.8256 - val_loss: 0.7355
# Epoch 65/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8436 - loss: 0.6885
# Epoch 65: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8454 - loss: 0.6863 - val_accuracy: 0.8322 - val_loss: 0.7241
# Epoch 66/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8513 - loss: 0.6763
# Epoch 66: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8471 - loss: 0.6834 - val_accuracy: 0.8490 - val_loss: 0.6703
# Epoch 67/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8467 - loss: 0.6852
# Epoch 67: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8483 - loss: 0.6796 - val_accuracy: 0.8228 - val_loss: 0.7641
# Epoch 68/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8478 - loss: 0.6764
# Epoch 68: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8476 - loss: 0.6829 - val_accuracy: 0.8355 - val_loss: 0.7048
# Epoch 69/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8496 - loss: 0.6734
# Epoch 69: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8492 - loss: 0.6759 - val_accuracy: 0.8419 - val_loss: 0.6926
# Epoch 70/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8473 - loss: 0.6792
# Epoch 70: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.8501 - loss: 0.6757 - val_accuracy: 0.8594 - val_loss: 0.6509
# Epoch 71/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8530 - loss: 0.6648
# Epoch 71: val_loss did not improve from 0.64930
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8526 - loss: 0.6688 - val_accuracy: 0.8373 - val_loss: 0.7030
# Epoch 72/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8522 - loss: 0.6627
# Epoch 72: val_loss improved from 0.64930 to 0.62114, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 72: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8530 - loss: 0.6668 - val_accuracy: 0.8670 - val_loss: 0.6211
# Epoch 73/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8523 - loss: 0.6674
# Epoch 73: val_loss did not improve from 0.62114
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8524 - loss: 0.6687 - val_accuracy: 0.8598 - val_loss: 0.6441
# Epoch 74/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8557 - loss: 0.6617
# Epoch 74: val_loss did not improve from 0.62114
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8536 - loss: 0.6654 - val_accuracy: 0.8694 - val_loss: 0.6228
# Epoch 75/200
# 507/625 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8553 - loss: 0.6656
# Epoch 75: val_loss did not improve from 0.62114
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8543 - loss: 0.6632 - val_accuracy: 0.8547 - val_loss: 0.6652
# Epoch 76/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8576 - loss: 0.6606
# Epoch 76: val_loss did not improve from 0.62114
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8564 - loss: 0.6600 - val_accuracy: 0.8654 - val_loss: 0.6306
# Epoch 77/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8589 - loss: 0.6479
# Epoch 77: val_loss did not improve from 0.62114
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8605 - loss: 0.6498 - val_accuracy: 0.8585 - val_loss: 0.6451
# Epoch 78/200
# 477/625 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8601 - loss: 0.6521
# Epoch 78: val_loss improved from 0.62114 to 0.61004, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 78: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8586 - loss: 0.6577 - val_accuracy: 0.8711 - val_loss: 0.6100
# Epoch 79/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8608 - loss: 0.6458
# Epoch 79: val_loss did not improve from 0.61004
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8583 - loss: 0.6551 - val_accuracy: 0.8636 - val_loss: 0.6403
# Epoch 80/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8593 - loss: 0.6497
# Epoch 80: val_loss improved from 0.61004 to 0.59604, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 80: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8609 - loss: 0.6504 - val_accuracy: 0.8785 - val_loss: 0.5960
# Epoch 81/200
# 615/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8601 - loss: 0.6516
# Epoch 81: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8594 - loss: 0.6517 - val_accuracy: 0.8620 - val_loss: 0.6367
# Epoch 82/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8602 - loss: 0.6517
# Epoch 82: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8603 - loss: 0.6496 - val_accuracy: 0.8455 - val_loss: 0.6827
# Epoch 83/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8584 - loss: 0.6503
# Epoch 83: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8609 - loss: 0.6456 - val_accuracy: 0.8581 - val_loss: 0.6576
# Epoch 84/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8637 - loss: 0.6431
# Epoch 84: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8637 - loss: 0.6436 - val_accuracy: 0.8594 - val_loss: 0.6460
# Epoch 85/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8635 - loss: 0.6391
# Epoch 85: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8608 - loss: 0.6430 - val_accuracy: 0.8558 - val_loss: 0.6582
# Epoch 86/200
# 564/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8637 - loss: 0.6389
# Epoch 86: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8629 - loss: 0.6412 - val_accuracy: 0.8693 - val_loss: 0.6199
# Epoch 87/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8658 - loss: 0.6389
# Epoch 87: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8648 - loss: 0.6379 - val_accuracy: 0.8720 - val_loss: 0.6129
# Epoch 88/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8644 - loss: 0.6400
# Epoch 88: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8635 - loss: 0.6411 - val_accuracy: 0.8649 - val_loss: 0.6311
# Epoch 89/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8637 - loss: 0.6375
# Epoch 89: val_loss did not improve from 0.59604
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8624 - loss: 0.6402 - val_accuracy: 0.8703 - val_loss: 0.6221
# Epoch 90/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8662 - loss: 0.6319
# Epoch 90: val_loss improved from 0.59604 to 0.58958, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 90: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8655 - loss: 0.6353 - val_accuracy: 0.8790 - val_loss: 0.5896
# Epoch 91/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8638 - loss: 0.6367
# Epoch 91: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8655 - loss: 0.6337 - val_accuracy: 0.8677 - val_loss: 0.6297
# Epoch 92/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8689 - loss: 0.6265
# Epoch 92: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8683 - loss: 0.6273 - val_accuracy: 0.8764 - val_loss: 0.6064
# Epoch 93/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8661 - loss: 0.6367
# Epoch 93: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.8665 - loss: 0.6320 - val_accuracy: 0.8578 - val_loss: 0.6534
# Epoch 94/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8658 - loss: 0.6335
# Epoch 94: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8661 - loss: 0.6332 - val_accuracy: 0.8588 - val_loss: 0.6530
# Epoch 95/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8679 - loss: 0.6293
# Epoch 95: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8694 - loss: 0.6244 - val_accuracy: 0.8453 - val_loss: 0.7016
# Epoch 96/200
# 548/625 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8670 - loss: 0.6293
# Epoch 96: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8680 - loss: 0.6305 - val_accuracy: 0.8696 - val_loss: 0.6264
# Epoch 97/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8728 - loss: 0.6195
# Epoch 97: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8727 - loss: 0.6207 - val_accuracy: 0.8688 - val_loss: 0.6257
# Epoch 98/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8706 - loss: 0.6227
# Epoch 98: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8713 - loss: 0.6219 - val_accuracy: 0.8735 - val_loss: 0.6181
# Epoch 99/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8727 - loss: 0.6166
# Epoch 99: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8707 - loss: 0.6226 - val_accuracy: 0.8747 - val_loss: 0.6074
# Epoch 100/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8717 - loss: 0.6193
# Epoch 100: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8737 - loss: 0.6170 - val_accuracy: 0.8701 - val_loss: 0.6175
# Epoch 101/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8749 - loss: 0.6122
# Epoch 101: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8735 - loss: 0.6163 - val_accuracy: 0.8725 - val_loss: 0.6121
# Epoch 102/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8747 - loss: 0.6122
# Epoch 102: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8725 - loss: 0.6164 - val_accuracy: 0.8701 - val_loss: 0.6202
# Epoch 103/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8742 - loss: 0.6139
# Epoch 103: val_loss did not improve from 0.58958
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8736 - loss: 0.6131 - val_accuracy: 0.8808 - val_loss: 0.5929
# Epoch 104/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8741 - loss: 0.6140
# Epoch 104: val_loss improved from 0.58958 to 0.58796, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 104: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.8727 - loss: 0.6177 - val_accuracy: 0.8831 - val_loss: 0.5880
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8778 - loss: 0.6020
# Epoch 105: val_loss did not improve from 0.58796
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8769 - loss: 0.6069 - val_accuracy: 0.8670 - val_loss: 0.6215
# Epoch 106/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8775 - loss: 0.6086
# Epoch 106: val_loss did not improve from 0.58796
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8775 - loss: 0.6078 - val_accuracy: 0.8734 - val_loss: 0.6176
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8763 - loss: 0.6102
# Epoch 107: val_loss did not improve from 0.58796
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8747 - loss: 0.6119 - val_accuracy: 0.8694 - val_loss: 0.6224
# Epoch 108/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8748 - loss: 0.6074
# Epoch 108: val_loss did not improve from 0.58796
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8751 - loss: 0.6105 - val_accuracy: 0.8760 - val_loss: 0.6074
# Epoch 109/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8786 - loss: 0.6055
# Epoch 109: val_loss improved from 0.58796 to 0.57976, saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
#
# Epoch 109: finished saving model to /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_best.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8789 - loss: 0.6043 - val_accuracy: 0.8859 - val_loss: 0.5798
# Epoch 110/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8790 - loss: 0.6030
# Epoch 110: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8762 - loss: 0.6073 - val_accuracy: 0.8811 - val_loss: 0.5983
# Epoch 111/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8795 - loss: 0.6016
# Epoch 111: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8798 - loss: 0.6027 - val_accuracy: 0.8871 - val_loss: 0.5815
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8806 - loss: 0.5977
# Epoch 112: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8782 - loss: 0.6048 - val_accuracy: 0.8770 - val_loss: 0.6039
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8814 - loss: 0.5982
# Epoch 113: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8801 - loss: 0.6011 - val_accuracy: 0.8698 - val_loss: 0.6232
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8804 - loss: 0.5977
# Epoch 114: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8787 - loss: 0.6015 - val_accuracy: 0.8741 - val_loss: 0.6088
# Epoch 115/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8815 - loss: 0.5956
# Epoch 115: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8802 - loss: 0.5981 - val_accuracy: 0.8761 - val_loss: 0.6110
# Epoch 116/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8797 - loss: 0.5980
# Epoch 116: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8806 - loss: 0.5981 - val_accuracy: 0.8546 - val_loss: 0.6706
# Epoch 117/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8807 - loss: 0.6000
# Epoch 117: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8805 - loss: 0.6000 - val_accuracy: 0.8734 - val_loss: 0.6113
# Epoch 118/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8808 - loss: 0.5997
# Epoch 118: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8813 - loss: 0.5985 - val_accuracy: 0.8737 - val_loss: 0.6141
# Epoch 119/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8792 - loss: 0.5990
# Epoch 119: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8789 - loss: 0.5999 - val_accuracy: 0.8733 - val_loss: 0.6209
# Epoch 120/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8810 - loss: 0.5982
# Epoch 120: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.8834 - loss: 0.5925 - val_accuracy: 0.8840 - val_loss: 0.5893
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8831 - loss: 0.5935
# Epoch 121: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.8831 - loss: 0.5940 - val_accuracy: 0.8855 - val_loss: 0.5844
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8862 - loss: 0.5812
# Epoch 122: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8841 - loss: 0.5878 - val_accuracy: 0.8713 - val_loss: 0.6274
# Epoch 123/200
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8849 - loss: 0.5868
# Epoch 123: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8835 - loss: 0.5892 - val_accuracy: 0.8614 - val_loss: 0.6468
# Epoch 124/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8835 - loss: 0.5910
# Epoch 124: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8840 - loss: 0.5893 - val_accuracy: 0.8793 - val_loss: 0.5993
# Epoch 125/200
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8838 - loss: 0.5938
# Epoch 125: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8833 - loss: 0.5933 - val_accuracy: 0.8786 - val_loss: 0.6024
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8842 - loss: 0.5896
# Epoch 126: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.8831 - loss: 0.5910 - val_accuracy: 0.8715 - val_loss: 0.6262
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8873 - loss: 0.5832
# Epoch 127: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8863 - loss: 0.5847 - val_accuracy: 0.8843 - val_loss: 0.5846
# Epoch 128/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8839 - loss: 0.5887
# Epoch 128: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.8860 - loss: 0.5858 - val_accuracy: 0.8860 - val_loss: 0.5817
# Epoch 129/200
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8843 - loss: 0.5863
# Epoch 129: val_loss did not improve from 0.57976
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.8842 - loss: 0.5894 - val_accuracy: 0.8875 - val_loss: 0.5799
# Epoch 129: early stopping
# Restoring model weights from the end of the best epoch: 109.
# 📊 Extracting final metrics for CNN - VGG-like Tuned...
# ✅ Success! Performance log updated at: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/data/model_performance_report.csv
# {'model_name': 'CNN - VGG-like Tuned',
#  'num_params': 1442090,
#  'train_time_sec': 1213.52,
#  'timestamp': '2026-02-18 23:58',
#  'accuracy': 0.8801,
#  'precision': 0.8811991007380001,
#  'recall': 0.8801,
#  'f1': 0.8787575020292859,
#  'support': 10000,
#  'final_accuracy': 0.8841750025749207,
#  'final_loss': 0.5893629193305969,
#  'final_val_accuracy': 0.887499988079071,
#  'final_val_loss': 0.5799243450164795,
#  'epochs_trained': 129}

# %% [markdown]
# ## 9. Test evaluation

# %%
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Test accuracy (best weights): {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Test accuracy (best weights): 0.8801
# Test loss: 0.5999

# %% [markdown]
# ## 10. Plots for report (accuracy and loss curves)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print("Generating predictions...")
y_true, y_pred = predict_and_resolve_labels(model=model, data=test_generator, verbose=0)

cm = compute_confusion_matrix(y_true, y_pred)
plot_confusion_matrix_notebook01(
    confusion=cm,
    class_names=class_names,
    title='Confusion Matrix - Custom VGG Model',
)

print("\nClassification Report (VGG):")
print(build_classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Generating predictions...
# Classification Report (VGG):
#               precision    recall  f1-score   support
#
#     airplane     0.9266    0.8710    0.8979      1000
#   automobile     0.9293    0.9600    0.9444      1000
#         bird     0.8944    0.8300    0.8610      1000
#          cat     0.8242    0.7030    0.7588      1000
#         deer     0.8793    0.8600    0.8696      1000
#          dog     0.8518    0.7930    0.8213      1000
#         frog     0.7997    0.9660    0.8750      1000
#        horse     0.9266    0.9210    0.9238      1000
#         ship     0.9244    0.9420    0.9331      1000
#        truck     0.8557    0.9550    0.9026      1000
#
#     accuracy                         0.8801     10000
#    macro avg     0.8812    0.8801    0.8788     10000
# weighted avg     0.8812    0.8801    0.8788     10000

# %%
curves_path = os.path.join(REPORTS_DIR, "vgg_bn_tuned_curves.png")
plot_training_curves_notebook01(
    history=history,
    save_path=curves_path,
)

print("Saved curves to:", curves_path)
# Out:
# Saved curves to: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/reports/vgg_bn_tuned_curves.png

# %% [markdown]
# ## 11. Save model

# %%
final_model_path = os.path.join(MODELS_DIR, "vgg_bn_tuned_final.keras")
model.save(final_model_path)
print("Saved:", final_model_path)
# Out:
# Saved: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_tuned_final.keras
